# %% [markdown]
# ### 作業
# 請嘗試使用 flip (左右翻轉) 來做 augmentation 以降低人臉關鍵點檢測的 loss
#
# Note: 圖像 flip 之後，groundtruth 的關鍵點也要跟著 flip 哦

# %% [markdown]
# ### 範例
# 接下來的程式碼會示範如何定義一個簡單的 CNN model

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
# 使用 colab 環境的同學請執行以下程式碼
# %tensorflow_version 1.x # 確保 colob 中使用的 tensorflow 是 1.x 版本而不是 tensorflow 2
# import tensorflow as tf
# print(tf.__version__)

# import os
# from google.colab import drive 
# drive.mount('/content/gdrive') # 將 google drive 掛載在 colob，
# %cd 'gdrive/My Drive'
# os.system("mkdir cupoy_cv_part4") # 可以自己改路徑
# %cd cupoy_cv_part4 # 可以自己改路徑

# %%
# 讀取資料集以及做前處理的函數
def load_data(dirname):
    # 讀取 csv 文件
    data = pd.read_csv(dirname)
    # 過濾有缺失值的 row
    data = data.dropna()

    # 將圖片像素值讀取為 numpy array 的形態
    data['Image'] = data['Image'].apply(lambda img: np.fromstring(img, sep=' ')).values 

    # 單獨把圖像 array 抽取出來
    imgs = np.vstack(data['Image'].values)/255
    # reshape 為 96 x 96
    imgs = imgs.reshape(data.shape[0], 96, 96)
    # 轉換為 float
    imgs = imgs.astype(np.float32)
    
    # 提取坐標的部分
    points = data[data.columns[:-1]].values

    # 轉換為 float
    points = points.astype(np.float32)

    # normalize 坐標值到 [-0.5, 0.5]
    points = points/96 - 0.5
    
    return imgs, points

# %%
# 讀取資料
imgs_train, points_train = load_data(dirname = 'training.csv')
print("圖像資料:", imgs_train.shape, "\n關鍵點資料:", points_train.shape)
# Out:
# 圖像資料: (2140, 96, 96)
# 關鍵點資料: (2140, 30)

# %%
from keras.models import Sequential
from keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Dropout
# Out:
# Using TensorFlow backend.

# %%
# 回傳定義好的 model 的函數
def get_model():
    # 定義人臉關鍵點檢測網路
    model = Sequential()

    # 定義神經網路的輸入
    model.add(Conv2D(filters=16, kernel_size=3, activation='relu', input_shape=(96, 96, 1)))
    model.add(MaxPooling2D(pool_size=2))

    model.add(Conv2D(filters=32, kernel_size=3, activation='relu'))
    model.add(MaxPooling2D(pool_size=2))

    model.add(Conv2D(filters=64, kernel_size=3, activation='relu'))
    model.add(MaxPooling2D(pool_size=2))

    model.add(Conv2D(filters=128, kernel_size=3, activation='relu'))
    model.add(MaxPooling2D(pool_size=2))

    model.add(Flatten())
    model.add(Dense(512, activation='relu'))
    model.add(Dropout(0.2))
    model.add(Dense(512, activation='relu'))
    model.add(Dropout(0.2))

    # 最後輸出 30 維的向量，也就是 15 個關鍵點的值
    model.add(Dense(30))
    return model

# %%
model = get_model()
# 配置 loss funtion 和 optimizer
model.compile(loss='mean_squared_error', optimizer='adam')

# %%
# 印出網路結構
model.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_1 (Conv2D)            (None, 94, 94, 16)        160
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 47, 47, 16)        0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 45, 45, 32)        4640
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 22, 22, 32)        0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 20, 20, 64)        18496
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 10, 10, 64)        0
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 8, 8, 128)         73856
# _________________________________________________________________
# max_pooling2d_4 (MaxPooling2 (None, 4, 4, 128)         0
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 2048)              0
# _________________________________________________________________
# dense_1 (Dense)              (None, 512)               1049088
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 512)               0
# _________________________________________________________________
# dense_2 (Dense)              (None, 512)               262656
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 512)               0
# _________________________________________________________________
# dense_3 (Dense)              (None, 30)                15390
# =================================================================
# Total params: 1,424,286
# Trainable params: 1,424,286
# Non-trainable params: 0
# _________________________________________________________________

# %%
from keras.callbacks import ModelCheckpoint, History
# model checkpoint 
checkpoint = ModelCheckpoint('best_weights.h5', verbose=1, save_best_only=True)
hist = History()

# %%
# training the model
hist_model = model.fit(imgs_train.reshape(-1, 96, 96, 1), 
                       points_train, 
                       validation_split=0.2, batch_size=64, callbacks=[checkpoint, hist],
                       shuffle=True, epochs=150, verbose=1)
# save the model weights
model.save_weights('weights.h5')
# save the model
model.save('model.h5')
# Out:
# Train on 1712 samples, validate on 428 samples
# Epoch 1/150
# 1712/1712 [==============================] - 5s 3ms/step - loss: 0.0076 - val_loss: 0.0023
#
# Epoch 00001: val_loss improved from inf to 0.00234, saving model to best_weights.h5
# Epoch 2/150
# 1712/1712 [==============================] - 1s 364us/step - loss: 0.0019 - val_loss: 0.0019
#
# Epoch 00002: val_loss improved from 0.00234 to 0.00193, saving model to best_weights.h5
# Epoch 3/150
# 1712/1712 [==============================] - 1s 354us/step - loss: 0.0014 - val_loss: 0.0019
#
# Epoch 00003: val_loss improved from 0.00193 to 0.00191, saving model to best_weights.h5
# Epoch 4/150
# 1712/1712 [==============================] - 1s 341us/step - loss: 0.0012 - val_loss: 0.0020
#
# Epoch 00004: val_loss did not improve from 0.00191
# Epoch 5/150
# 1712/1712 [==============================] - 1s 358us/step - loss: 0.0011 - val_loss: 0.0019
#
# Epoch 00005: val_loss did not improve from 0.00191
# Epoch 6/150
# 1712/1712 [==============================] - 1s 349us/step - loss: 0.0011 - val_loss: 0.0019
#
# Epoch 00006: val_loss improved from 0.00191 to 0.00189, saving model to best_weights.h5
# Epoch 7/150
# 1712/1712 [==============================] - 1s 346us/step - loss: 9.7168e-04 - val_loss: 0.0017
#
# Epoch 00007: val_loss improved from 0.00189 to 0.00169, saving model to best_weights.h5
# Epoch 8/150
# 1712/1712 [==============================] - 1s 355us/step - loss: 8.3772e-04 - val_loss: 0.0016
#
# Epoch 00008: val_loss improved from 0.00169 to 0.00158, saving model to best_weights.h5
# Epoch 9/150
# 1712/1712 [==============================] - 1s 347us/step - loss: 7.0784e-04 - val_loss: 0.0014
#
# Epoch 00009: val_loss improved from 0.00158 to 0.00140, saving model to best_weights.h5
# Epoch 10/150
# 1712/1712 [==============================] - 1s 371us/step - loss: 6.3153e-04 - val_loss: 0.0013
#
# Epoch 00010: val_loss improved from 0.00140 to 0.00125, saving model to best_weights.h5
# Epoch 11/150
# 1712/1712 [==============================] - 1s 350us/step - loss: 5.6859e-04 - val_loss: 0.0012
#
# Epoch 00011: val_loss improved from 0.00125 to 0.00116, saving model to best_weights.h5
# Epoch 12/150
# 1712/1712 [==============================] - 1s 351us/step - loss: 5.0693e-04 - val_loss: 0.0011
#
# Epoch 00012: val_loss improved from 0.00116 to 0.00106, saving model to best_weights.h5
# Epoch 13/150
# 1712/1712 [==============================] - 1s 350us/step - loss: 4.7332e-04 - val_loss: 0.0010
#
# Epoch 00013: val_loss improved from 0.00106 to 0.00101, saving model to best_weights.h5
# Epoch 14/150
# 1712/1712 [==============================] - 1s 358us/step - loss: 4.4190e-04 - val_loss: 9.8365e-04
#
# Epoch 00014: val_loss improved from 0.00101 to 0.00098, saving model to best_weights.h5
# Epoch 15/150
# 1712/1712 [==============================] - 1s 370us/step - loss: 4.2619e-04 - val_loss: 9.9238e-04
#
# Epoch 00015: val_loss did not improve from 0.00098
# Epoch 16/150
# 1712/1712 [==============================] - 1s 372us/step - loss: 4.0267e-04 - val_loss: 9.3846e-04
#
# Epoch 00016: val_loss improved from 0.00098 to 0.00094, saving model to best_weights.h5
# Epoch 17/150
# 1712/1712 [==============================] - 1s 351us/step - loss: 3.7894e-04 - val_loss: 9.0360e-04
#
# Epoch 00017: val_loss improved from 0.00094 to 0.00090, saving model to best_weights.h5
# Epoch 18/150
# 1712/1712 [==============================] - 1s 348us/step - loss: 3.6302e-04 - val_loss: 8.8519e-04
#
# Epoch 00018: val_loss improved from 0.00090 to 0.00089, saving model to best_weights.h5
# Epoch 19/150
# 1712/1712 [==============================] - 1s 371us/step - loss: 3.5220e-04 - val_loss: 8.6801e-04
#
# Epoch 00019: val_loss improved from 0.00089 to 0.00087, saving model to best_weights.h5
# Epoch 20/150
# 1712/1712 [==============================] - 1s 358us/step - loss: 3.3027e-04 - val_loss: 8.6156e-04
#
# Epoch 00020: val_loss improved from 0.00087 to 0.00086, saving model to best_weights.h5
# Epoch 21/150
# 1712/1712 [==============================] - 1s 351us/step - loss: 3.2620e-04 - val_loss: 8.3459e-04
#
# Epoch 00021: val_loss improved from 0.00086 to 0.00083, saving model to best_weights.h5
# Epoch 22/150
# 1712/1712 [==============================] - 1s 348us/step - loss: 3.3223e-04 - val_loss: 8.7224e-04
#
# Epoch 00022: val_loss did not improve from 0.00083
# Epoch 23/150
# 1712/1712 [==============================] - 1s 381us/step - loss: 3.1088e-04 - val_loss: 8.5041e-04
#
# Epoch 00023: val_loss did not improve from 0.00083
# Epoch 24/150
# 1712/1712 [==============================] - 1s 365us/step - loss: 2.9675e-04 - val_loss: 8.5001e-04
#
# Epoch 00024: val_loss did not improve from 0.00083
# Epoch 25/150
# 1712/1712 [==============================] - 1s 362us/step - loss: 2.9324e-04 - val_loss: 8.2270e-04
#
# Epoch 00025: val_loss improved from 0.00083 to 0.00082, saving model to best_weights.h5
# Epoch 26/150
# 1712/1712 [==============================] - 1s 362us/step - loss: 2.8074e-04 - val_loss: 8.2501e-04
#
# Epoch 00026: val_loss did not improve from 0.00082
# Epoch 27/150
# 1712/1712 [==============================] - 1s 357us/step - loss: 2.6963e-04 - val_loss: 8.4750e-04
#
# Epoch 00027: val_loss did not improve from 0.00082
# Epoch 28/150
# 1712/1712 [==============================] - 1s 350us/step - loss: 2.6551e-04 - val_loss: 8.5282e-04
#
# Epoch 00028: val_loss did not improve from 0.00082
# Epoch 29/150
# 1712/1712 [==============================] - 1s 365us/step - loss: 2.6194e-04 - val_loss: 9.8264e-04
#
# Epoch 00029: val_loss did not improve from 0.00082
# Epoch 30/150
# 1712/1712 [==============================] - 1s 366us/step - loss: 2.7834e-04 - val_loss: 8.8004e-04
#
# Epoch 00030: val_loss did not improve from 0.00082
# Epoch 31/150
# 1712/1712 [==============================] - 1s 346us/step - loss: 2.5817e-04 - val_loss: 7.8331e-04
#
# Epoch 00031: val_loss improved from 0.00082 to 0.00078, saving model to best_weights.h5
# Epoch 32/150
# 1712/1712 [==============================] - 1s 377us/step - loss: 2.4946e-04 - val_loss: 7.9485e-04
#
# Epoch 00032: val_loss did not improve from 0.00078
# Epoch 33/150
# 1712/1712 [==============================] - 1s 349us/step - loss: 2.4015e-04 - val_loss: 7.8889e-04
#
# Epoch 00033: val_loss did not improve from 0.00078
# Epoch 34/150
# 1712/1712 [==============================] - 1s 362us/step - loss: 2.3754e-04 - val_loss: 8.0077e-04
#
# Epoch 00034: val_loss did not improve from 0.00078
# Epoch 35/150
# 1712/1712 [==============================] - 1s 365us/step - loss: 2.3325e-04 - val_loss: 7.8336e-04
#
# Epoch 00035: val_loss did not improve from 0.00078
# Epoch 36/150
# 1712/1712 [==============================] - 1s 370us/step - loss: 2.3477e-04 - val_loss: 8.2040e-04
#
# Epoch 00036: val_loss did not improve from 0.00078
# Epoch 37/150
# 1712/1712 [==============================] - 1s 351us/step - loss: 2.2843e-04 - val_loss: 8.1242e-04
#
# Epoch 00037: val_loss did not improve from 0.00078
# Epoch 38/150
# 1712/1712 [==============================] - 1s 368us/step - loss: 2.1925e-04 - val_loss: 7.8966e-04
#
# Epoch 00038: val_loss did not improve from 0.00078
# Epoch 39/150
# 1712/1712 [==============================] - 1s 350us/step - loss: 2.1483e-04 - val_loss: 7.8097e-04
#
# Epoch 00039: val_loss improved from 0.00078 to 0.00078, saving model to best_weights.h5
# Epoch 40/150
# 1712/1712 [==============================] - 1s 351us/step - loss: 2.1753e-04 - val_loss: 8.1496e-04
#
# Epoch 00040: val_loss did not improve from 0.00078
# Epoch 41/150
# 1712/1712 [==============================] - 1s 351us/step - loss: 2.1752e-04 - val_loss: 7.9025e-04
#
# Epoch 00041: val_loss did not improve from 0.00078
# Epoch 42/150
# 1712/1712 [==============================] - 1s 363us/step - loss: 2.1513e-04 - val_loss: 8.1075e-04
#
# Epoch 00042: val_loss did not improve from 0.00078
# Epoch 43/150
# 1712/1712 [==============================] - 1s 356us/step - loss: 2.0139e-04 - val_loss: 7.4959e-04
#
# Epoch 00043: val_loss improved from 0.00078 to 0.00075, saving model to best_weights.h5
# Epoch 44/150
# 1712/1712 [==============================] - 1s 377us/step - loss: 1.9555e-04 - val_loss: 7.6413e-04
#
# Epoch 00044: val_loss did not improve from 0.00075
# Epoch 45/150
# 1712/1712 [==============================] - 1s 382us/step - loss: 2.0175e-04 - val_loss: 7.5947e-04
#
# Epoch 00045: val_loss did not improve from 0.00075
# Epoch 46/150
# 1712/1712 [==============================] - 1s 377us/step - loss: 1.9074e-04 - val_loss: 7.7303e-04
#
# Epoch 00046: val_loss did not improve from 0.00075
# Epoch 47/150
# 1712/1712 [==============================] - 1s 350us/step - loss: 1.9182e-04 - val_loss: 7.7311e-04
#
# Epoch 00047: val_loss did not improve from 0.00075
# Epoch 48/150
# 1712/1712 [==============================] - 1s 372us/step - loss: 1.8790e-04 - val_loss: 7.6126e-04
#
# Epoch 00048: val_loss did not improve from 0.00075
# Epoch 49/150
# 1712/1712 [==============================] - 1s 377us/step - loss: 1.9474e-04 - val_loss: 7.4629e-04
#
# Epoch 00049: val_loss improved from 0.00075 to 0.00075, saving model to best_weights.h5
# Epoch 50/150
# 1712/1712 [==============================] - 1s 365us/step - loss: 1.8879e-04 - val_loss: 7.7508e-04
#
# Epoch 00050: val_loss did not improve from 0.00075
# Epoch 51/150
# 1712/1712 [==============================] - 1s 368us/step - loss: 1.8171e-04 - val_loss: 7.3730e-04
#
# Epoch 00051: val_loss improved from 0.00075 to 0.00074, saving model to best_weights.h5
# Epoch 52/150
# 1712/1712 [==============================] - 1s 347us/step - loss: 1.8068e-04 - val_loss: 7.9591e-04
#
# Epoch 00052: val_loss did not improve from 0.00074
# Epoch 53/150
# 1712/1712 [==============================] - 1s 348us/step - loss: 1.7787e-04 - val_loss: 7.8480e-04
#
# Epoch 00053: val_loss did not improve from 0.00074
# Epoch 54/150
# 1712/1712 [==============================] - 1s 347us/step - loss: 1.8136e-04 - val_loss: 7.6327e-04
#
# Epoch 00054: val_loss did not improve from 0.00074
# Epoch 55/150
# 1712/1712 [==============================] - 1s 347us/step - loss: 1.7610e-04 - val_loss: 7.4898e-04
#
# Epoch 00055: val_loss did not improve from 0.00074
# Epoch 56/150
# 1712/1712 [==============================] - 1s 351us/step - loss: 1.8090e-04 - val_loss: 7.2898e-04
#
# Epoch 00056: val_loss improved from 0.00074 to 0.00073, saving model to best_weights.h5
# Epoch 57/150
# 1712/1712 [==============================] - 1s 396us/step - loss: 1.7918e-04 - val_loss: 7.7124e-04
#
# Epoch 00057: val_loss did not improve from 0.00073
# Epoch 58/150
# 1712/1712 [==============================] - 1s 387us/step - loss: 1.7021e-04 - val_loss: 7.3645e-04
#
# Epoch 00058: val_loss did not improve from 0.00073
# Epoch 59/150
# 1712/1712 [==============================] - 1s 376us/step - loss: 1.6981e-04 - val_loss: 7.5720e-04
#
# Epoch 00059: val_loss did not improve from 0.00073
# Epoch 60/150
# 1712/1712 [==============================] - 1s 378us/step - loss: 1.6843e-04 - val_loss: 7.7803e-04
#
# Epoch 00060: val_loss did not improve from 0.00073
# Epoch 61/150
# 1712/1712 [==============================] - 1s 398us/step - loss: 1.6792e-04 - val_loss: 7.3397e-04
#
# Epoch 00061: val_loss did not improve from 0.00073
# Epoch 62/150
# 1712/1712 [==============================] - 1s 386us/step - loss: 1.6819e-04 - val_loss: 7.3729e-04
#
# Epoch 00062: val_loss did not improve from 0.00073
# Epoch 63/150
# 1712/1712 [==============================] - 1s 401us/step - loss: 1.6765e-04 - val_loss: 7.5285e-04
#
# Epoch 00063: val_loss did not improve from 0.00073
# Epoch 64/150
# 1712/1712 [==============================] - 1s 407us/step - loss: 1.6405e-04 - val_loss: 7.5786e-04
#
# Epoch 00064: val_loss did not improve from 0.00073
# Epoch 65/150
# 1712/1712 [==============================] - 1s 404us/step - loss: 1.5689e-04 - val_loss: 7.5224e-04
#
# Epoch 00065: val_loss did not improve from 0.00073
# Epoch 66/150
# 1712/1712 [==============================] - 1s 350us/step - loss: 1.5778e-04 - val_loss: 7.7245e-04
#
# Epoch 00066: val_loss did not improve from 0.00073
# Epoch 67/150
# 1712/1712 [==============================] - 1s 394us/step - loss: 1.5326e-04 - val_loss: 7.3803e-04
#
# Epoch 00067: val_loss did not improve from 0.00073
# Epoch 68/150
# 1712/1712 [==============================] - 1s 381us/step - loss: 1.5328e-04 - val_loss: 7.6593e-04
#
# Epoch 00068: val_loss did not improve from 0.00073
# Epoch 69/150
# 1712/1712 [==============================] - 1s 348us/step - loss: 1.4896e-04 - val_loss: 7.6996e-04
#
# Epoch 00069: val_loss did not improve from 0.00073
# Epoch 70/150
# 1712/1712 [==============================] - 1s 346us/step - loss: 1.5031e-04 - val_loss: 7.6285e-04
#
# Epoch 00070: val_loss did not improve from 0.00073
# Epoch 71/150
# 1712/1712 [==============================] - 1s 351us/step - loss: 1.5429e-04 - val_loss: 7.3325e-04
#
# Epoch 00071: val_loss did not improve from 0.00073
# Epoch 72/150
# 1712/1712 [==============================] - 1s 352us/step - loss: 1.4744e-04 - val_loss: 7.6326e-04
#
# Epoch 00072: val_loss did not improve from 0.00073
# Epoch 73/150
# 1712/1712 [==============================] - 1s 345us/step - loss: 1.4544e-04 - val_loss: 7.3917e-04
#
# Epoch 00073: val_loss did not improve from 0.00073
# Epoch 74/150
# 1712/1712 [==============================] - 1s 346us/step - loss: 1.4783e-04 - val_loss: 7.4921e-04
#
# Epoch 00074: val_loss did not improve from 0.00073
# Epoch 75/150
# 1712/1712 [==============================] - 1s 344us/step - loss: 1.4382e-04 - val_loss: 7.3639e-04
#
# Epoch 00075: val_loss did not improve from 0.00073
# Epoch 76/150
# 1712/1712 [==============================] - 1s 347us/step - loss: 1.4141e-04 - val_loss: 8.1162e-04
#
# Epoch 00076: val_loss did not improve from 0.00073
# Epoch 77/150
# 1712/1712 [==============================] - 1s 384us/step - loss: 1.4082e-04 - val_loss: 7.5917e-04
#
# Epoch 00077: val_loss did not improve from 0.00073
# Epoch 78/150
# 1712/1712 [==============================] - 1s 345us/step - loss: 1.4233e-04 - val_loss: 7.7523e-04
#
# Epoch 00078: val_loss did not improve from 0.00073
# Epoch 79/150
# 1712/1712 [==============================] - 1s 344us/step - loss: 1.3607e-04 - val_loss: 7.5775e-04
#
# Epoch 00079: val_loss did not improve from 0.00073
# Epoch 80/150
# 1712/1712 [==============================] - 1s 345us/step - loss: 1.3947e-04 - val_loss: 7.4289e-04
#
# Epoch 00080: val_loss did not improve from 0.00073
# Epoch 81/150
# 1712/1712 [==============================] - 1s 347us/step - loss: 1.4208e-04 - val_loss: 7.2718e-04
#
# Epoch 00081: val_loss improved from 0.00073 to 0.00073, saving model to best_weights.h5
# Epoch 82/150
# 1712/1712 [==============================] - 1s 367us/step - loss: 1.3938e-04 - val_loss: 7.4691e-04
#
# Epoch 00082: val_loss did not improve from 0.00073
# Epoch 83/150
# 1712/1712 [==============================] - 1s 348us/step - loss: 1.3295e-04 - val_loss: 7.5630e-04
#
# Epoch 00083: val_loss did not improve from 0.00073
# Epoch 84/150
# 1712/1712 [==============================] - 1s 347us/step - loss: 1.3343e-04 - val_loss: 7.5221e-04
#
# Epoch 00084: val_loss did not improve from 0.00073
# Epoch 85/150
# 1712/1712 [==============================] - 1s 345us/step - loss: 1.2933e-04 - val_loss: 7.6431e-04
#
# Epoch 00085: val_loss did not improve from 0.00073
# Epoch 86/150
# 1712/1712 [==============================] - 1s 345us/step - loss: 1.3118e-04 - val_loss: 7.4210e-04
#
# Epoch 00086: val_loss did not improve from 0.00073
# Epoch 87/150
# 1712/1712 [==============================] - 1s 345us/step - loss: 1.2829e-04 - val_loss: 7.3985e-04
#
# Epoch 00087: val_loss did not improve from 0.00073
# Epoch 88/150
# 1712/1712 [==============================] - 1s 345us/step - loss: 1.2583e-04 - val_loss: 7.6706e-04
#
# Epoch 00088: val_loss did not improve from 0.00073
# Epoch 89/150
# 1712/1712 [==============================] - 1s 345us/step - loss: 1.2800e-04 - val_loss: 7.6295e-04
#
# Epoch 00089: val_loss did not improve from 0.00073
# Epoch 90/150
# 1712/1712 [==============================] - 1s 345us/step - loss: 1.2578e-04 - val_loss: 7.6968e-04
#
# Epoch 00090: val_loss did not improve from 0.00073
# Epoch 91/150
# 1712/1712 [==============================] - 1s 343us/step - loss: 1.2239e-04 - val_loss: 7.5675e-04
#
# Epoch 00091: val_loss did not improve from 0.00073
# Epoch 92/150
# 1712/1712 [==============================] - 1s 345us/step - loss: 1.2390e-04 - val_loss: 7.5121e-04
#
# Epoch 00092: val_loss did not improve from 0.00073
# Epoch 93/150
# 1712/1712 [==============================] - 1s 345us/step - loss: 1.2341e-04 - val_loss: 7.6037e-04
#
# Epoch 00093: val_loss did not improve from 0.00073
# Epoch 94/150
# 1712/1712 [==============================] - 1s 344us/step - loss: 1.2244e-04 - val_loss: 7.5349e-04
# Epoch 00094: val_loss did not improve from 0.00073
# Epoch 95/150
# 1712/1712 [==============================] - 1s 347us/step - loss: 1.1960e-04 - val_loss: 7.5804e-04
#
# Epoch 00095: val_loss did not improve from 0.00073
# Epoch 96/150
# 1712/1712 [==============================] - 1s 346us/step - loss: 1.2275e-04 - val_loss: 7.5902e-04
#
# Epoch 00096: val_loss did not improve from 0.00073
# Epoch 97/150
# 1712/1712 [==============================] - 1s 346us/step - loss: 1.1912e-04 - val_loss: 7.8564e-04
#
# Epoch 00097: val_loss did not improve from 0.00073
# Epoch 98/150
# 1712/1712 [==============================] - 1s 345us/step - loss: 1.2086e-04 - val_loss: 7.5465e-04
#
# Epoch 00098: val_loss did not improve from 0.00073
# Epoch 99/150
# 1712/1712 [==============================] - 1s 347us/step - loss: 1.2265e-04 - val_loss: 7.5628e-04
#
# Epoch 00099: val_loss did not improve from 0.00073
# Epoch 100/150
# 1712/1712 [==============================] - 1s 355us/step - loss: 1.1781e-04 - val_loss: 7.5653e-04
#
# Epoch 00100: val_loss did not improve from 0.00073
# Epoch 101/150
# 1712/1712 [==============================] - 1s 346us/step - loss: 1.1600e-04 - val_loss: 7.6005e-04
#
# Epoch 00101: val_loss did not improve from 0.00073
# Epoch 102/150
# 1712/1712 [==============================] - 1s 345us/step - loss: 1.1671e-04 - val_loss: 7.4854e-04
#
# Epoch 00102: val_loss did not improve from 0.00073
# Epoch 103/150
# 1712/1712 [==============================] - 1s 345us/step - loss: 1.1612e-04 - val_loss: 7.5899e-04
#
# Epoch 00103: val_loss did not improve from 0.00073
# Epoch 104/150
# 1712/1712 [==============================] - 1s 372us/step - loss: 1.1320e-04 - val_loss: 7.4420e-04
#
# Epoch 00104: val_loss did not improve from 0.00073
# Epoch 105/150
# 1712/1712 [==============================] - 1s 379us/step - loss: 1.0934e-04 - val_loss: 7.5700e-04
#
# Epoch 00105: val_loss did not improve from 0.00073
# Epoch 106/150
# 1712/1712 [==============================] - 1s 373us/step - loss: 1.0920e-04 - val_loss: 7.4183e-04
#
# Epoch 00106: val_loss did not improve from 0.00073
# Epoch 107/150
# 1712/1712 [==============================] - 1s 374us/step - loss: 1.1107e-04 - val_loss: 7.4289e-04
#
# Epoch 00107: val_loss did not improve from 0.00073
# Epoch 108/150
# 1712/1712 [==============================] - 1s 385us/step - loss: 1.1175e-04 - val_loss: 7.5554e-04
#
# Epoch 00108: val_loss did not improve from 0.00073
# Epoch 109/150
# 1712/1712 [==============================] - 1s 386us/step - loss: 1.1096e-04 - val_loss: 7.5773e-04
#
# Epoch 00109: val_loss did not improve from 0.00073
# Epoch 110/150
# 1712/1712 [==============================] - 1s 378us/step - loss: 1.0959e-04 - val_loss: 7.5405e-04
#
# Epoch 00110: val_loss did not improve from 0.00073
# Epoch 111/150
# 1712/1712 [==============================] - 1s 358us/step - loss: 1.0758e-04 - val_loss: 7.6735e-04
#
# Epoch 00111: val_loss did not improve from 0.00073
# Epoch 112/150
# 1712/1712 [==============================] - 1s 421us/step - loss: 1.0984e-04 - val_loss: 7.4241e-04
#
# Epoch 00112: val_loss did not improve from 0.00073
# Epoch 113/150
# 1712/1712 [==============================] - 1s 369us/step - loss: 1.0736e-04 - val_loss: 7.5563e-04
#
# Epoch 00113: val_loss did not improve from 0.00073
# Epoch 114/150
# 1712/1712 [==============================] - 1s 346us/step - loss: 1.0687e-04 - val_loss: 7.6024e-04
#
# Epoch 00114: val_loss did not improve from 0.00073
# Epoch 115/150
# 1712/1712 [==============================] - 1s 414us/step - loss: 1.0522e-04 - val_loss: 7.7903e-04
#
# Epoch 00115: val_loss did not improve from 0.00073
# Epoch 116/150
# 1712/1712 [==============================] - 1s 346us/step - loss: 1.0428e-04 - val_loss: 7.4296e-04
#
# Epoch 00116: val_loss did not improve from 0.00073
# Epoch 117/150
# 1712/1712 [==============================] - 1s 347us/step - loss: 1.0267e-04 - val_loss: 7.7147e-04
#
# Epoch 00117: val_loss did not improve from 0.00073
# Epoch 118/150
# 1712/1712 [==============================] - 1s 385us/step - loss: 1.0658e-04 - val_loss: 7.6916e-04
#
# Epoch 00118: val_loss did not improve from 0.00073
# Epoch 119/150
# 1712/1712 [==============================] - 1s 358us/step - loss: 1.0310e-04 - val_loss: 7.7134e-04
#
# Epoch 00119: val_loss did not improve from 0.00073
# Epoch 120/150
# 1712/1712 [==============================] - 1s 390us/step - loss: 1.0442e-04 - val_loss: 7.4917e-04
#
# Epoch 00120: val_loss did not improve from 0.00073
# Epoch 121/150
# 1712/1712 [==============================] - 1s 369us/step - loss: 1.0196e-04 - val_loss: 7.6518e-04
#
# Epoch 00121: val_loss did not improve from 0.00073
# Epoch 122/150
# 1712/1712 [==============================] - 1s 361us/step - loss: 1.0406e-04 - val_loss: 7.5316e-04
#
# Epoch 00122: val_loss did not improve from 0.00073
# Epoch 123/150
# 1712/1712 [==============================] - 1s 360us/step - loss: 1.0405e-04 - val_loss: 7.6490e-04
#
# Epoch 00123: val_loss did not improve from 0.00073
# Epoch 124/150
# 1712/1712 [==============================] - 1s 359us/step - loss: 1.0136e-04 - val_loss: 7.5442e-04
#
# Epoch 00124: val_loss did not improve from 0.00073
# Epoch 125/150
# 1712/1712 [==============================] - 1s 369us/step - loss: 9.5750e-05 - val_loss: 7.5835e-04
#
# Epoch 00125: val_loss did not improve from 0.00073
# Epoch 126/150
# 1712/1712 [==============================] - 1s 361us/step - loss: 9.9528e-05 - val_loss: 7.7166e-04
#
# Epoch 00126: val_loss did not improve from 0.00073
# Epoch 127/150
# 1712/1712 [==============================] - 1s 351us/step - loss: 9.7348e-05 - val_loss: 7.6902e-04
#
# Epoch 00127: val_loss did not improve from 0.00073
# Epoch 128/150
# 1712/1712 [==============================] - 1s 349us/step - loss: 9.6376e-05 - val_loss: 7.6517e-04
#
# Epoch 00128: val_loss did not improve from 0.00073
# Epoch 129/150
# 1712/1712 [==============================] - 1s 369us/step - loss: 9.5032e-05 - val_loss: 7.3231e-04
#
# Epoch 00129: val_loss did not improve from 0.00073
# Epoch 130/150
# 1712/1712 [==============================] - 1s 350us/step - loss: 9.4967e-05 - val_loss: 7.7991e-04
#
# Epoch 00130: val_loss did not improve from 0.00073
# Epoch 131/150
# 1712/1712 [==============================] - 1s 352us/step - loss: 9.4083e-05 - val_loss: 7.5046e-04
#
# Epoch 00131: val_loss did not improve from 0.00073
# Epoch 132/150
# 1712/1712 [==============================] - 1s 382us/step - loss: 9.2975e-05 - val_loss: 7.7029e-04
#
# Epoch 00132: val_loss did not improve from 0.00073
# Epoch 133/150
# 1712/1712 [==============================] - 1s 359us/step - loss: 9.3620e-05 - val_loss: 7.5431e-04
#
# Epoch 00133: val_loss did not improve from 0.00073
# Epoch 134/150
# 1712/1712 [==============================] - 1s 363us/step - loss: 9.5588e-05 - val_loss: 7.6142e-04
#
# Epoch 00134: val_loss did not improve from 0.00073
# Epoch 135/150
# 1712/1712 [==============================] - 1s 362us/step - loss: 9.4708e-05 - val_loss: 7.2377e-04
#
# Epoch 00135: val_loss improved from 0.00073 to 0.00072, saving model to best_weights.h5
# Epoch 136/150
# 1712/1712 [==============================] - 1s 354us/step - loss: 9.2332e-05 - val_loss: 7.7301e-04
#
# Epoch 00136: val_loss did not improve from 0.00072
# Epoch 137/150
# 1712/1712 [==============================] - 1s 353us/step - loss: 9.2559e-05 - val_loss: 7.4972e-04
#
# Epoch 00137: val_loss did not improve from 0.00072
# Epoch 138/150
# 1712/1712 [==============================] - 1s 348us/step - loss: 9.2038e-05 - val_loss: 8.0970e-04
#
# Epoch 00138: val_loss did not improve from 0.00072
# Epoch 139/150
# 1712/1712 [==============================] - 1s 356us/step - loss: 9.5876e-05 - val_loss: 7.6650e-04
#
# Epoch 00139: val_loss did not improve from 0.00072
# Epoch 140/150
# 1712/1712 [==============================] - 1s 349us/step - loss: 9.3755e-05 - val_loss: 7.7000e-04
#
# Epoch 00140: val_loss did not improve from 0.00072
# Epoch 141/150
# 1712/1712 [==============================] - 1s 349us/step - loss: 9.3058e-05 - val_loss: 7.7096e-04
#
# Epoch 00141: val_loss did not improve from 0.00072
# Epoch 142/150
# 1712/1712 [==============================] - 1s 365us/step - loss: 9.0653e-05 - val_loss: 7.7383e-04
#
# Epoch 00142: val_loss did not improve from 0.00072
# Epoch 143/150
# 1712/1712 [==============================] - 1s 359us/step - loss: 9.1514e-05 - val_loss: 7.4780e-04
# Epoch 00143: val_loss did not improve from 0.00072
# Epoch 144/150
# 1712/1712 [==============================] - 1s 366us/step - loss: 8.8698e-05 - val_loss: 8.0156e-04
#
# Epoch 00144: val_loss did not improve from 0.00072
# Epoch 145/150
# 1712/1712 [==============================] - 1s 354us/step - loss: 8.9148e-05 - val_loss: 7.6682e-04
#
# Epoch 00145: val_loss did not improve from 0.00072
# Epoch 146/150
# 1712/1712 [==============================] - 1s 350us/step - loss: 8.6861e-05 - val_loss: 7.8292e-04
#
# Epoch 00146: val_loss did not improve from 0.00072
# Epoch 147/150
# 1712/1712 [==============================] - 1s 347us/step - loss: 8.7379e-05 - val_loss: 7.4160e-04
#
# Epoch 00147: val_loss did not improve from 0.00072
# Epoch 148/150
# 1712/1712 [==============================] - 1s 383us/step - loss: 9.0716e-05 - val_loss: 7.5078e-04
#
# Epoch 00148: val_loss did not improve from 0.00072
# Epoch 149/150
# 1712/1712 [==============================] - 1s 348us/step - loss: 8.8829e-05 - val_loss: 7.6557e-04
#
# Epoch 00149: val_loss did not improve from 0.00072
# Epoch 150/150
# 1712/1712 [==============================] - 1s 372us/step - loss: 8.6477e-05 - val_loss: 7.6628e-04
#
# Epoch 00150: val_loss did not improve from 0.00072

# %%
# loss 值的圖
plt.title('Optimizer : Adam', fontsize=10)
plt.ylabel('Loss', fontsize=16)
plt.plot(hist_model.history['loss'], color='b', label='Training Loss')
plt.plot(hist_model.history['val_loss'], color='r', label='Validation Loss')
plt.legend(loc='upper right')

# %% [markdown]
# ### 觀察 model 在 testing 上的結果

# %%
# 讀取測試資料集
imgs_test, _ = load_data(dirname = 'test.csv')

# %%
# 在灰階圖像上畫關鍵點的函數
def plot_keypoints(img, points):
    plt.imshow(img, cmap='gray')
    for i in range(0,30,2):
        plt.scatter((points[i] + 0.5)*96, (points[i+1]+0.5)*96, color='red')

# %%
fig = plt.figure(figsize=(15,15))
# 在測試集圖片上用剛剛訓練好的模型做關鍵點的預測
points_test = model.predict(imgs_test.reshape(imgs_test.shape[0], 96, 96, 1))

for i in range(16):
    ax = fig.add_subplot(4, 4, i + 1, xticks=[], yticks=[])
    plot_keypoints(imgs_test[i], np.squeeze(points_test[i]))

# %% [markdown]
# 目前為止，大致可以觀察到，直接使用簡單的模型以及訓練方式在這組數據上應該可以在訓練集和測試集上都得到一個還不錯的結果，說明這組資料其實不會很難。

# %%
model_with_augment = get_model()
model_with_augment.compile(loss='mean_squared_error', optimizer='adam')

# %%
# Your code
# 實現圖片以及關機點 label 做左右翻轉的函數
def augment_data(img, points):
    rows, cols = img.shape
    new_img = np.copy(img)
    
    # 翻轉圖片
    for i in range(96):
        for j in range(48):
            temp = img[i][j]
            new_img[i][j] = img[i][cols-j-1]
            new_img[i][cols-j-1] = temp
            
    # 翻轉關鍵點 label
    new_points = np.copy(points)
    for i in range(0,30,2):
        new_points[i] = -points[i]
    
    # 調整對稱的 label
    new_points_temp = np.copy(new_points)
    new_points[0:2] = new_points_temp[2:4]
    new_points[2:4] = new_points_temp[0:2]
    new_points[4:6] = new_points_temp[8:10]
    new_points[6:8] = new_points_temp[10:12]
    new_points[8:10] = new_points_temp[4:6]
    new_points[10:12] = new_points_temp[6:8]
    new_points[12:14] = new_points_temp[16:18]
    new_points[14:16] = new_points_temp[18:20]
    new_points[16:18] = new_points_temp[12:14]
    new_points[18:20] = new_points_temp[14:16]
    new_points[22:24] = new_points_temp[24:26]
    new_points[24:26] = new_points_temp[22:24]
        
    return new_img, new_points

# %%
flip_img, flip_points = augment_data(imgs_train[0], points_train[0])

fig = plt.figure()
ax = fig.add_subplot(1, 2, 1, xticks=[], yticks=[])
plot_keypoints(imgs_train[0], points_train[0]) # 原來的圖片
ax = fig.add_subplot(1, 2, 2, xticks=[], yticks=[])
plot_keypoints(flip_img, flip_points) # 翻轉後的圖片

# %%
# 創建 list
aug_imgs_train = []
aug_points_train = []

# 對所有原始資料做 augmentation
for i in range(imgs_train.shape[0]):
    # 做左右翻轉
    aug_img, aug_point = augment_data(imgs_train[i], points_train[i])
    
    # append 原始資料
    aug_imgs_train.append(imgs_train[i])
    aug_points_train.append(points_train[i]) 
    
    # append 做過 augmentation 後的資料
    aug_imgs_train.append(aug_img)
    aug_points_train.append(aug_point) 

# convert to numpy
aug_imgs_train = np.array(aug_imgs_train)   
aug_points_train = np.copy(aug_points_train)

print(aug_imgs_train.shape)
print(aug_points_train.shape)
# Out:
# (4280, 96, 96)
# (4280, 30)

# %%
checkpoint_aug = ModelCheckpoint('best_weights_augment.h5', verbose=1, save_best_only=True)
# training the model
hist_model_aug = model_with_augment.fit(aug_imgs_train.reshape(aug_imgs_train.shape[0], 96, 96, 1), aug_points_train, 
                           validation_split=0.2, batch_size=64, callbacks=[checkpoint_aug, hist],
                           shuffle=True, epochs=150, verbose=1)
# Out:
# Train on 3424 samples, validate on 856 samples
# Epoch 1/150
# 3424/3424 [==============================] - 2s 634us/step - loss: 0.0059 - val_loss: 0.0020
#
# Epoch 00001: val_loss improved from inf to 0.00201, saving model to best_weights_augment.h5
# Epoch 2/150
# 3424/3424 [==============================] - 1s 351us/step - loss: 0.0015 - val_loss: 0.0019
#
# Epoch 00002: val_loss improved from 0.00201 to 0.00187, saving model to best_weights_augment.h5
# Epoch 3/150
# 3424/3424 [==============================] - 1s 358us/step - loss: 0.0012 - val_loss: 0.0019
#
# Epoch 00003: val_loss did not improve from 0.00187
# Epoch 4/150
# 3424/3424 [==============================] - 1s 387us/step - loss: 0.0011 - val_loss: 0.0018
#
# Epoch 00004: val_loss improved from 0.00187 to 0.00176, saving model to best_weights_augment.h5
# Epoch 5/150
# 3424/3424 [==============================] - 1s 378us/step - loss: 8.9000e-04 - val_loss: 0.0016
#
# Epoch 00005: val_loss improved from 0.00176 to 0.00165, saving model to best_weights_augment.h5
# Epoch 6/150
# 3424/3424 [==============================] - 1s 360us/step - loss: 7.3720e-04 - val_loss: 0.0013
#
# Epoch 00006: val_loss improved from 0.00165 to 0.00133, saving model to best_weights_augment.h5
# Epoch 7/150
# 3424/3424 [==============================] - 1s 377us/step - loss: 6.1311e-04 - val_loss: 0.0011
#
# Epoch 00007: val_loss improved from 0.00133 to 0.00114, saving model to best_weights_augment.h5
# Epoch 8/150
# 3424/3424 [==============================] - 1s 389us/step - loss: 5.3688e-04 - val_loss: 0.0011
#
# Epoch 00008: val_loss improved from 0.00114 to 0.00108, saving model to best_weights_augment.h5
# Epoch 9/150
# 3424/3424 [==============================] - 1s 421us/step - loss: 4.8315e-04 - val_loss: 9.3271e-04
#
# Epoch 00009: val_loss improved from 0.00108 to 0.00093, saving model to best_weights_augment.h5
# Epoch 10/150
# 3424/3424 [==============================] - 1s 381us/step - loss: 4.4156e-04 - val_loss: 9.2342e-04
#
# Epoch 00010: val_loss improved from 0.00093 to 0.00092, saving model to best_weights_augment.h5
# Epoch 11/150
# 3424/3424 [==============================] - 1s 363us/step - loss: 4.1375e-04 - val_loss: 8.5026e-04
#
# Epoch 00011: val_loss improved from 0.00092 to 0.00085, saving model to best_weights_augment.h5
# Epoch 12/150
# 3424/3424 [==============================] - 1s 401us/step - loss: 3.8043e-04 - val_loss: 8.0103e-04
#
# Epoch 00012: val_loss improved from 0.00085 to 0.00080, saving model to best_weights_augment.h5
# Epoch 13/150
# 3424/3424 [==============================] - 1s 386us/step - loss: 3.5593e-04 - val_loss: 7.7751e-04
#
# Epoch 00013: val_loss improved from 0.00080 to 0.00078, saving model to best_weights_augment.h5
# Epoch 14/150
# 3424/3424 [==============================] - 1s 378us/step - loss: 3.4389e-04 - val_loss: 7.7566e-04
#
# Epoch 00014: val_loss improved from 0.00078 to 0.00078, saving model to best_weights_augment.h5
# Epoch 15/150
# 3424/3424 [==============================] - 1s 419us/step - loss: 3.2832e-04 - val_loss: 7.3167e-04
#
# Epoch 00015: val_loss improved from 0.00078 to 0.00073, saving model to best_weights_augment.h5
# Epoch 16/150
# 3424/3424 [==============================] - 1s 403us/step - loss: 3.1672e-04 - val_loss: 8.0866e-04
#
# Epoch 00016: val_loss did not improve from 0.00073
# Epoch 17/150
# 3424/3424 [==============================] - 1s 364us/step - loss: 3.0550e-04 - val_loss: 7.1369e-04
#
# Epoch 00017: val_loss improved from 0.00073 to 0.00071, saving model to best_weights_augment.h5
# Epoch 18/150
# 3424/3424 [==============================] - 1s 402us/step - loss: 2.9082e-04 - val_loss: 7.8829e-04
#
# Epoch 00018: val_loss did not improve from 0.00071
# Epoch 19/150
# 3424/3424 [==============================] - 2s 470us/step - loss: 2.7964e-04 - val_loss: 7.2079e-04
#
# Epoch 00019: val_loss did not improve from 0.00071
# Epoch 20/150
# 3424/3424 [==============================] - 2s 463us/step - loss: 2.7225e-04 - val_loss: 7.1575e-04
#
# Epoch 00020: val_loss did not improve from 0.00071
# Epoch 21/150
# 3424/3424 [==============================] - 1s 374us/step - loss: 2.6534e-04 - val_loss: 6.7022e-04
#
# Epoch 00021: val_loss improved from 0.00071 to 0.00067, saving model to best_weights_augment.h5
# Epoch 22/150
# 3424/3424 [==============================] - 1s 358us/step - loss: 2.5969e-04 - val_loss: 6.7287e-04
#
# Epoch 00022: val_loss did not improve from 0.00067
# Epoch 23/150
# 3424/3424 [==============================] - 1s 374us/step - loss: 2.5185e-04 - val_loss: 6.5225e-04
#
# Epoch 00023: val_loss improved from 0.00067 to 0.00065, saving model to best_weights_augment.h5
# Epoch 24/150
# 3424/3424 [==============================] - 1s 369us/step - loss: 2.5112e-04 - val_loss: 6.5848e-04
#
# Epoch 00024: val_loss did not improve from 0.00065
# Epoch 25/150
# 3424/3424 [==============================] - 1s 362us/step - loss: 2.3817e-04 - val_loss: 7.3234e-04
#
# Epoch 00025: val_loss did not improve from 0.00065
# Epoch 26/150
# 3424/3424 [==============================] - 1s 387us/step - loss: 2.3274e-04 - val_loss: 6.3603e-04
#
# Epoch 00026: val_loss improved from 0.00065 to 0.00064, saving model to best_weights_augment.h5
# Epoch 27/150
# 3424/3424 [==============================] - 1s 382us/step - loss: 2.3051e-04 - val_loss: 6.6402e-04
#
# Epoch 00027: val_loss did not improve from 0.00064
# Epoch 28/150
# 3424/3424 [==============================] - 1s 359us/step - loss: 2.2755e-04 - val_loss: 6.5271e-04
#
# Epoch 00028: val_loss did not improve from 0.00064
# Epoch 29/150
# 3424/3424 [==============================] - 1s 359us/step - loss: 2.1784e-04 - val_loss: 6.4157e-04
#
# Epoch 00029: val_loss did not improve from 0.00064
# Epoch 30/150
# 3424/3424 [==============================] - 1s 369us/step - loss: 2.1206e-04 - val_loss: 6.3863e-04
#
# Epoch 00030: val_loss did not improve from 0.00064
# Epoch 31/150
# 3424/3424 [==============================] - 1s 369us/step - loss: 2.0918e-04 - val_loss: 6.2694e-04
#
# Epoch 00031: val_loss improved from 0.00064 to 0.00063, saving model to best_weights_augment.h5
# Epoch 32/150
# 3424/3424 [==============================] - 1s 375us/step - loss: 2.0513e-04 - val_loss: 6.1805e-04
#
# Epoch 00032: val_loss improved from 0.00063 to 0.00062, saving model to best_weights_augment.h5
# Epoch 33/150
# 3424/3424 [==============================] - 1s 363us/step - loss: 2.0187e-04 - val_loss: 6.3165e-04
#
# Epoch 00033: val_loss did not improve from 0.00062
# Epoch 34/150
# 3424/3424 [==============================] - 1s 357us/step - loss: 1.9511e-04 - val_loss: 6.3830e-04
#
# Epoch 00034: val_loss did not improve from 0.00062
# Epoch 35/150
# 3424/3424 [==============================] - 1s 356us/step - loss: 1.9215e-04 - val_loss: 6.9861e-04
#
# Epoch 00035: val_loss did not improve from 0.00062
# Epoch 36/150
# 3424/3424 [==============================] - 1s 366us/step - loss: 1.9522e-04 - val_loss: 6.2222e-04
#
# Epoch 00036: val_loss did not improve from 0.00062
# Epoch 37/150
# 3424/3424 [==============================] - 1s 368us/step - loss: 1.8538e-04 - val_loss: 6.5501e-04
#
# Epoch 00037: val_loss did not improve from 0.00062
# Epoch 38/150
# 3424/3424 [==============================] - 1s 358us/step - loss: 1.8842e-04 - val_loss: 6.4432e-04
#
# Epoch 00038: val_loss did not improve from 0.00062
# Epoch 39/150
# 3424/3424 [==============================] - 1s 357us/step - loss: 1.8191e-04 - val_loss: 6.2015e-04
#
# Epoch 00039: val_loss did not improve from 0.00062
# Epoch 40/150
# 3424/3424 [==============================] - 1s 366us/step - loss: 1.7812e-04 - val_loss: 6.3295e-04
#
# Epoch 00040: val_loss did not improve from 0.00062
# Epoch 41/150
# 3424/3424 [==============================] - 1s 366us/step - loss: 1.7748e-04 - val_loss: 6.2768e-04
#
# Epoch 00041: val_loss did not improve from 0.00062
# Epoch 42/150
# 3424/3424 [==============================] - 1s 376us/step - loss: 1.7489e-04 - val_loss: 6.4511e-04
#
# Epoch 00042: val_loss did not improve from 0.00062
# Epoch 43/150
# 3424/3424 [==============================] - 1s 379us/step - loss: 1.7128e-04 - val_loss: 6.3332e-04
#
# Epoch 00043: val_loss did not improve from 0.00062
# Epoch 44/150
# 3424/3424 [==============================] - 1s 435us/step - loss: 1.6682e-04 - val_loss: 6.2422e-04
#
# Epoch 00044: val_loss did not improve from 0.00062
# Epoch 45/150
# 3424/3424 [==============================] - 1s 360us/step - loss: 1.6548e-04 - val_loss: 6.3371e-04
#
# Epoch 00045: val_loss did not improve from 0.00062
# Epoch 46/150
# 3424/3424 [==============================] - 1s 368us/step - loss: 1.6419e-04 - val_loss: 6.1604e-04
#
# Epoch 00046: val_loss improved from 0.00062 to 0.00062, saving model to best_weights_augment.h5
# Epoch 47/150
# 3424/3424 [==============================] - 1s 382us/step - loss: 1.6264e-04 - val_loss: 6.1241e-04
#
# Epoch 00047: val_loss improved from 0.00062 to 0.00061, saving model to best_weights_augment.h5
# Epoch 48/150
# 3424/3424 [==============================] - 1s 361us/step - loss: 1.5844e-04 - val_loss: 6.5708e-04
#
# Epoch 00048: val_loss did not improve from 0.00061
# Epoch 49/150
# 3424/3424 [==============================] - 1s 371us/step - loss: 1.5796e-04 - val_loss: 6.0161e-04
#
# Epoch 00049: val_loss improved from 0.00061 to 0.00060, saving model to best_weights_augment.h5
# Epoch 50/150
# 3424/3424 [==============================] - 1s 369us/step - loss: 1.5911e-04 - val_loss: 5.9545e-04
#
# Epoch 00050: val_loss improved from 0.00060 to 0.00060, saving model to best_weights_augment.h5
# Epoch 51/150
# 3424/3424 [==============================] - 1s 368us/step - loss: 1.5453e-04 - val_loss: 6.3431e-04
#
# Epoch 00051: val_loss did not improve from 0.00060
# Epoch 52/150
# 3424/3424 [==============================] - 1s 357us/step - loss: 1.5398e-04 - val_loss: 6.1807e-04
#
# Epoch 00052: val_loss did not improve from 0.00060
# Epoch 53/150
# 3424/3424 [==============================] - 1s 360us/step - loss: 1.4962e-04 - val_loss: 6.5737e-04
#
# Epoch 00053: val_loss did not improve from 0.00060
# Epoch 54/150
# 3424/3424 [==============================] - 1s 355us/step - loss: 1.5062e-04 - val_loss: 6.1998e-04
#
# Epoch 00054: val_loss did not improve from 0.00060
# Epoch 55/150
# 3424/3424 [==============================] - 1s 357us/step - loss: 1.4607e-04 - val_loss: 6.1322e-04
#
# Epoch 00055: val_loss did not improve from 0.00060
# Epoch 56/150
# 3424/3424 [==============================] - 1s 353us/step - loss: 1.4765e-04 - val_loss: 6.5201e-04
#
# Epoch 00056: val_loss did not improve from 0.00060
# Epoch 57/150
# 3424/3424 [==============================] - 1s 356us/step - loss: 1.4296e-04 - val_loss: 6.2654e-04
#
# Epoch 00057: val_loss did not improve from 0.00060
# Epoch 58/150
# 3424/3424 [==============================] - 1s 358us/step - loss: 1.4143e-04 - val_loss: 6.3487e-04
#
# Epoch 00058: val_loss did not improve from 0.00060
# Epoch 59/150
# 3424/3424 [==============================] - 1s 359us/step - loss: 1.3937e-04 - val_loss: 6.0564e-04
#
# Epoch 00059: val_loss did not improve from 0.00060
# Epoch 60/150
# 3424/3424 [==============================] - 1s 353us/step - loss: 1.3430e-04 - val_loss: 6.3200e-04
#
# Epoch 00060: val_loss did not improve from 0.00060
# Epoch 61/150
# 3424/3424 [==============================] - 1s 360us/step - loss: 1.3622e-04 - val_loss: 6.0607e-04
#
# Epoch 00061: val_loss did not improve from 0.00060
# Epoch 62/150
# 3424/3424 [==============================] - 1s 365us/step - loss: 1.3730e-04 - val_loss: 6.1153e-04
#
# Epoch 00062: val_loss did not improve from 0.00060
# Epoch 63/150
# 3424/3424 [==============================] - 1s 364us/step - loss: 1.3590e-04 - val_loss: 6.0640e-04
#
# Epoch 00063: val_loss did not improve from 0.00060
# Epoch 64/150
# 3424/3424 [==============================] - 1s 386us/step - loss: 1.3274e-04 - val_loss: 6.3967e-04
#
# Epoch 00064: val_loss did not improve from 0.00060
# Epoch 65/150
# 3424/3424 [==============================] - 1s 364us/step - loss: 1.3055e-04 - val_loss: 5.9982e-04
#
# Epoch 00065: val_loss did not improve from 0.00060
# Epoch 66/150
# 3424/3424 [==============================] - 1s 363us/step - loss: 1.2999e-04 - val_loss: 6.3344e-04
#
# Epoch 00066: val_loss did not improve from 0.00060
# Epoch 67/150
# 3424/3424 [==============================] - 1s 357us/step - loss: 1.2906e-04 - val_loss: 6.3759e-04 ETA: 0s - loss: 1.2912e-
#
# Epoch 00067: val_loss did not improve from 0.00060
# Epoch 68/150
# 3424/3424 [==============================] - 1s 369us/step - loss: 1.2677e-04 - val_loss: 6.0061e-04
#
# Epoch 00068: val_loss did not improve from 0.00060
# Epoch 69/150
# 3424/3424 [==============================] - 1s 417us/step - loss: 1.2659e-04 - val_loss: 6.0679e-04
#
# Epoch 00069: val_loss did not improve from 0.00060
# Epoch 70/150
# 3424/3424 [==============================] - 2s 505us/step - loss: 1.2394e-04 - val_loss: 6.4866e-04
#
# Epoch 00070: val_loss did not improve from 0.00060
# Epoch 71/150
# 3424/3424 [==============================] - 2s 505us/step - loss: 1.2167e-04 - val_loss: 5.9675e-04
#
# Epoch 00071: val_loss did not improve from 0.00060
# Epoch 72/150
# 3424/3424 [==============================] - 1s 392us/step - loss: 1.2361e-04 - val_loss: 5.9950e-04
#
# Epoch 00072: val_loss did not improve from 0.00060
# Epoch 73/150
# 3424/3424 [==============================] - 1s 352us/step - loss: 1.2740e-04 - val_loss: 5.8907e-04
#
# Epoch 00073: val_loss improved from 0.00060 to 0.00059, saving model to best_weights_augment.h5
# Epoch 74/150
# 3424/3424 [==============================] - 1s 361us/step - loss: 1.2314e-04 - val_loss: 6.2087e-04
#
# Epoch 00074: val_loss did not improve from 0.00059
# Epoch 75/150
# 3424/3424 [==============================] - 1s 394us/step - loss: 1.1969e-04 - val_loss: 6.0893e-04
#
# Epoch 00075: val_loss did not improve from 0.00059
# Epoch 76/150
# 3424/3424 [==============================] - 1s 389us/step - loss: 1.1881e-04 - val_loss: 6.0369e-04
#
# Epoch 00076: val_loss did not improve from 0.00059
# Epoch 77/150
# 3424/3424 [==============================] - 1s 398us/step - loss: 1.1615e-04 - val_loss: 6.0890e-04
#
# Epoch 00077: val_loss did not improve from 0.00059
# Epoch 78/150
# 3424/3424 [==============================] - 1s 401us/step - loss: 1.1712e-04 - val_loss: 5.9703e-04
#
# Epoch 00078: val_loss did not improve from 0.00059
# Epoch 79/150
# 3424/3424 [==============================] - 1s 437us/step - loss: 1.1717e-04 - val_loss: 6.3006e-04
#
# Epoch 00079: val_loss did not improve from 0.00059
# Epoch 80/150
# 3424/3424 [==============================] - 1s 381us/step - loss: 1.1450e-04 - val_loss: 6.1343e-04
#
# Epoch 00080: val_loss did not improve from 0.00059
# Epoch 81/150
# 3424/3424 [==============================] - 1s 384us/step - loss: 1.1725e-04 - val_loss: 6.1097e-04
#
# Epoch 00081: val_loss did not improve from 0.00059
# Epoch 82/150
# 3424/3424 [==============================] - 1s 377us/step - loss: 1.1388e-04 - val_loss: 6.0285e-04
#
# Epoch 00082: val_loss did not improve from 0.00059
# Epoch 83/150
# 3424/3424 [==============================] - 1s 397us/step - loss: 1.1456e-04 - val_loss: 6.0618e-04
#
# Epoch 00083: val_loss did not improve from 0.00059
# Epoch 84/150
# 3424/3424 [==============================] - 1s 385us/step - loss: 1.1632e-04 - val_loss: 5.9295e-04
#
# Epoch 00084: val_loss did not improve from 0.00059
# Epoch 85/150
# 3424/3424 [==============================] - 1s 405us/step - loss: 1.1576e-04 - val_loss: 6.3155e-04
#
# Epoch 00085: val_loss did not improve from 0.00059
# Epoch 86/150
# 3424/3424 [==============================] - 1s 394us/step - loss: 1.0847e-04 - val_loss: 6.1860e-04
#
# Epoch 00086: val_loss did not improve from 0.00059
# Epoch 87/150
# 3424/3424 [==============================] - 1s 395us/step - loss: 1.0959e-04 - val_loss: 6.1460e-04
#
# Epoch 00087: val_loss did not improve from 0.00059
# Epoch 88/150
# 3424/3424 [==============================] - 1s 395us/step - loss: 1.0874e-04 - val_loss: 6.2765e-04
#
# Epoch 00088: val_loss did not improve from 0.00059
# Epoch 89/150
# 3424/3424 [==============================] - 1s 391us/step - loss: 1.1125e-04 - val_loss: 6.2839e-04
#
# Epoch 00089: val_loss did not improve from 0.00059
# Epoch 90/150
# 3424/3424 [==============================] - 1s 383us/step - loss: 1.0916e-04 - val_loss: 6.0256e-04
#
# Epoch 00090: val_loss did not improve from 0.00059
# Epoch 91/150
# 3424/3424 [==============================] - 1s 362us/step - loss: 1.0746e-04 - val_loss: 6.5716e-04
#
# Epoch 00091: val_loss did not improve from 0.00059
# Epoch 92/150
# 3424/3424 [==============================] - 1s 370us/step - loss: 1.0705e-04 - val_loss: 6.0062e-04
#
# Epoch 00092: val_loss did not improve from 0.00059
# Epoch 93/150
# 3424/3424 [==============================] - 1s 389us/step - loss: 1.0630e-04 - val_loss: 6.1472e-04
#
# Epoch 00093: val_loss did not improve from 0.00059
# Epoch 94/150
# 3424/3424 [==============================] - 1s 394us/step - loss: 1.0674e-04 - val_loss: 5.9660e-04
#
# Epoch 00094: val_loss did not improve from 0.00059
# Epoch 95/150
# 3424/3424 [==============================] - 1s 373us/step - loss: 1.0582e-04 - val_loss: 6.3117e-04
#
# Epoch 00095: val_loss did not improve from 0.00059
# Epoch 96/150
# 3424/3424 [==============================] - 1s 347us/step - loss: 1.0355e-04 - val_loss: 6.1849e-04
#
# Epoch 00096: val_loss did not improve from 0.00059
# Epoch 97/150
# 3424/3424 [==============================] - 1s 374us/step - loss: 1.0306e-04 - val_loss: 6.0065e-04
#
# Epoch 00097: val_loss did not improve from 0.00059
# Epoch 98/150
# 3424/3424 [==============================] - 1s 366us/step - loss: 1.0179e-04 - val_loss: 5.9692e-04
#
# Epoch 00098: val_loss did not improve from 0.00059
# Epoch 99/150
# 3424/3424 [==============================] - 1s 363us/step - loss: 1.0216e-04 - val_loss: 5.8592e-04
#
# Epoch 00099: val_loss improved from 0.00059 to 0.00059, saving model to best_weights_augment.h5
# Epoch 100/150
# 3424/3424 [==============================] - ETA: 0s - loss: 1.0777e-0 - 1s 364us/step - loss: 1.0744e-04 - val_loss: 6.0840e-04
#
# Epoch 00100: val_loss did not improve from 0.00059
# Epoch 101/150
# 3424/3424 [==============================] - 1s 364us/step - loss: 1.0022e-04 - val_loss: 6.2859e-04
#
# Epoch 00101: val_loss did not improve from 0.00059
# Epoch 102/150
# 3424/3424 [==============================] - 1s 360us/step - loss: 1.0140e-04 - val_loss: 6.0337e-04
#
# Epoch 00102: val_loss did not improve from 0.00059
# Epoch 103/150
# 3424/3424 [==============================] - 1s 359us/step - loss: 1.0159e-04 - val_loss: 6.0693e-04
#
# Epoch 00103: val_loss did not improve from 0.00059
# Epoch 104/150
# 3424/3424 [==============================] - 1s 351us/step - loss: 1.0112e-04 - val_loss: 6.2498e-04
#
# Epoch 00104: val_loss did not improve from 0.00059
# Epoch 105/150
# 3424/3424 [==============================] - 1s 353us/step - loss: 1.0094e-04 - val_loss: 6.0535e-04
#
# Epoch 00105: val_loss did not improve from 0.00059
# Epoch 106/150
# 3424/3424 [==============================] - 1s 355us/step - loss: 9.7498e-05 - val_loss: 6.1596e-04
#
# Epoch 00106: val_loss did not improve from 0.00059
# Epoch 107/150
# 3424/3424 [==============================] - 1s 357us/step - loss: 1.0090e-04 - val_loss: 5.8963e-04
#
# Epoch 00107: val_loss did not improve from 0.00059
# Epoch 108/150
# 3424/3424 [==============================] - 1s 357us/step - loss: 1.0101e-04 - val_loss: 6.1645e-04
#
# Epoch 00108: val_loss did not improve from 0.00059
# Epoch 109/150
# 3424/3424 [==============================] - 1s 356us/step - loss: 9.8869e-05 - val_loss: 6.1684e-04
#
# Epoch 00109: val_loss did not improve from 0.00059
# Epoch 110/150
# 3424/3424 [==============================] - 1s 352us/step - loss: 9.5475e-05 - val_loss: 6.1653e-04
#
# Epoch 00110: val_loss did not improve from 0.00059
# Epoch 111/150
# 3424/3424 [==============================] - 1s 361us/step - loss: 9.7534e-05 - val_loss: 6.0037e-04
#
# Epoch 00111: val_loss did not improve from 0.00059
# Epoch 112/150
# 3424/3424 [==============================] - 1s 360us/step - loss: 9.7317e-05 - val_loss: 5.9934e-04
#
# Epoch 00112: val_loss did not improve from 0.00059
# Epoch 113/150
# 3424/3424 [==============================] - 1s 352us/step - loss: 9.9439e-05 - val_loss: 6.0996e-04
#
# Epoch 00113: val_loss did not improve from 0.00059
# Epoch 114/150
# 3424/3424 [==============================] - 1s 360us/step - loss: 9.5829e-05 - val_loss: 6.0624e-04
#
# Epoch 00114: val_loss did not improve from 0.00059
# Epoch 115/150
# 3424/3424 [==============================] - 1s 355us/step - loss: 9.7061e-05 - val_loss: 6.0268e-04
#
# Epoch 00115: val_loss did not improve from 0.00059
# Epoch 116/150
# 3424/3424 [==============================] - 1s 357us/step - loss: 9.7882e-05 - val_loss: 5.9848e-04
#
# Epoch 00116: val_loss did not improve from 0.00059
# Epoch 117/150
# 3424/3424 [==============================] - 1s 361us/step - loss: 9.7364e-05 - val_loss: 6.2106e-04
#
# Epoch 00117: val_loss did not improve from 0.00059
# Epoch 118/150
# 3424/3424 [==============================] - 1s 361us/step - loss: 9.6689e-05 - val_loss: 6.0562e-04
#
# Epoch 00118: val_loss did not improve from 0.00059
# Epoch 119/150
# 3424/3424 [==============================] - 1s 360us/step - loss: 9.5211e-05 - val_loss: 6.2117e-04
#
# Epoch 00119: val_loss did not improve from 0.00059
# Epoch 120/150
# 3424/3424 [==============================] - 1s 356us/step - loss: 9.5436e-05 - val_loss: 6.1528e-04
#
# Epoch 00120: val_loss did not improve from 0.00059
# Epoch 121/150
# 3424/3424 [==============================] - 1s 350us/step - loss: 9.4869e-05 - val_loss: 6.1511e-04
#
# Epoch 00121: val_loss did not improve from 0.00059
# Epoch 122/150
# 3424/3424 [==============================] - 1s 347us/step - loss: 9.2702e-05 - val_loss: 6.1991e-04
#
# Epoch 00122: val_loss did not improve from 0.00059
# Epoch 123/150
# 3424/3424 [==============================] - 1s 349us/step - loss: 9.2519e-05 - val_loss: 6.4242e-04
#
# Epoch 00123: val_loss did not improve from 0.00059
# Epoch 124/150
# 3424/3424 [==============================] - 1s 353us/step - loss: 9.6190e-05 - val_loss: 6.4257e-04
#
# Epoch 00124: val_loss did not improve from 0.00059
# Epoch 125/150
# 3424/3424 [==============================] - 1s 394us/step - loss: 9.1490e-05 - val_loss: 5.9738e-04
#
# Epoch 00125: val_loss did not improve from 0.00059
# Epoch 126/150
# 3424/3424 [==============================] - 1s 363us/step - loss: 9.4386e-05 - val_loss: 6.1159e-04
#
# Epoch 00126: val_loss did not improve from 0.00059
# Epoch 127/150
# 3424/3424 [==============================] - 1s 354us/step - loss: 9.3299e-05 - val_loss: 6.2279e-04
#
# Epoch 00127: val_loss did not improve from 0.00059
# Epoch 128/150
# 3424/3424 [==============================] - 1s 367us/step - loss: 9.2358e-05 - val_loss: 6.4140e-04
#
# Epoch 00128: val_loss did not improve from 0.00059
# Epoch 129/150
# 3424/3424 [==============================] - 1s 357us/step - loss: 9.2432e-05 - val_loss: 6.0823e-04
#
# Epoch 00129: val_loss did not improve from 0.00059
# Epoch 130/150
# 3424/3424 [==============================] - 1s 356us/step - loss: 9.4888e-05 - val_loss: 6.0999e-04
#
# Epoch 00130: val_loss did not improve from 0.00059
# Epoch 131/150
# 3424/3424 [==============================] - 1s 358us/step - loss: 9.1855e-05 - val_loss: 5.9181e-04
#
# Epoch 00131: val_loss did not improve from 0.00059
# Epoch 132/150
# 3424/3424 [==============================] - 1s 359us/step - loss: 8.9755e-05 - val_loss: 6.2109e-04
#
# Epoch 00132: val_loss did not improve from 0.00059
# Epoch 133/150
# 3424/3424 [==============================] - 1s 363us/step - loss: 8.9780e-05 - val_loss: 6.2753e-04
#
# Epoch 00133: val_loss did not improve from 0.00059
# Epoch 134/150
# 3424/3424 [==============================] - 1s 357us/step - loss: 8.9721e-05 - val_loss: 6.1520e-04
#
# Epoch 00134: val_loss did not improve from 0.00059
# Epoch 135/150
# 3424/3424 [==============================] - 1s 353us/step - loss: 9.0868e-05 - val_loss: 6.0761e-04
#
# Epoch 00135: val_loss did not improve from 0.00059
# Epoch 136/150
# 3424/3424 [==============================] - 1s 347us/step - loss: 8.8493e-05 - val_loss: 6.0067e-04
#
# Epoch 00136: val_loss did not improve from 0.00059
# Epoch 137/150
# 3424/3424 [==============================] - 1s 348us/step - loss: 8.7121e-05 - val_loss: 6.2107e-04
#
# Epoch 00137: val_loss did not improve from 0.00059
# Epoch 138/150
# 3424/3424 [==============================] - 1s 368us/step - loss: 8.7375e-05 - val_loss: 6.1706e-04s: 8.6950e
#
# Epoch 00138: val_loss did not improve from 0.00059
# Epoch 139/150
# 3424/3424 [==============================] - 1s 358us/step - loss: 8.8413e-05 - val_loss: 6.2459e-04
#
# Epoch 00139: val_loss did not improve from 0.00059
# Epoch 140/150
# 3424/3424 [==============================] - 1s 367us/step - loss: 8.9710e-05 - val_loss: 5.9279e-04
#
# Epoch 00140: val_loss did not improve from 0.00059
# Epoch 141/150
# 3424/3424 [==============================] - 1s 372us/step - loss: 8.6196e-05 - val_loss: 6.1577e-04
# Epoch 00141: val_loss did not improve from 0.00059
# Epoch 142/150
# 3424/3424 [==============================] - 1s 360us/step - loss: 8.8223e-05 - val_loss: 6.0762e-04
#
# Epoch 00142: val_loss did not improve from 0.00059
# Epoch 143/150
# 3424/3424 [==============================] - 1s 369us/step - loss: 8.6673e-05 - val_loss: 6.2151e-04
#
# Epoch 00143: val_loss did not improve from 0.00059
# Epoch 144/150
# 3424/3424 [==============================] - 1s 358us/step - loss: 8.6872e-05 - val_loss: 6.2909e-04
#
# Epoch 00144: val_loss did not improve from 0.00059
# Epoch 145/150
# 3424/3424 [==============================] - 1s 366us/step - loss: 8.6447e-05 - val_loss: 5.9826e-04
#
# Epoch 00145: val_loss did not improve from 0.00059
# Epoch 146/150
# 3424/3424 [==============================] - 1s 372us/step - loss: 8.6223e-05 - val_loss: 6.2152e-04
#
# Epoch 00146: val_loss did not improve from 0.00059
# Epoch 147/150
# 3424/3424 [==============================] - 1s 365us/step - loss: 8.6405e-05 - val_loss: 6.0999e-04
#
# Epoch 00147: val_loss did not improve from 0.00059
# Epoch 148/150
# 3424/3424 [==============================] - 1s 347us/step - loss: 8.7813e-05 - val_loss: 5.9680e-04
#
# Epoch 00148: val_loss did not improve from 0.00059
# Epoch 149/150
# 3424/3424 [==============================] - 1s 348us/step - loss: 8.7241e-05 - val_loss: 6.1285e-04
#
# Epoch 00149: val_loss did not improve from 0.00059
# Epoch 150/150
# 3424/3424 [==============================] - 1s 351us/step - loss: 8.2761e-05 - val_loss: 6.2415e-04
#
# Epoch 00150: val_loss did not improve from 0.00059

# %%
# loss 值的圖
plt.title('Optimizer : Adam', fontsize=10)
plt.ylabel('Loss', fontsize=16)
plt.plot(hist_model_aug.history['loss'], color='b', label='Training Loss')
plt.plot(hist_model_aug.history['val_loss'], color='r', label='Validation Loss')
plt.legend(loc='upper right')

# %% [markdown]
# ### 觀察 model 在 testing 上的結果

# %%
# 讀取測試資料集
imgs_test, _ = load_data(dirname = 'test.csv')

# %%
# 在灰階圖像上畫關鍵點的函數
def plot_keypoints(img, points):
    plt.imshow(img, cmap='gray')
    for i in range(0,30,2):
        plt.scatter((points[i] + 0.5)*96, (points[i+1]+0.5)*96, color='red')

# %%
fig = plt.figure(figsize=(15,15))
# 在測試集圖片上用剛剛訓練好的模型做關鍵點的預測
points_test = model_with_augment.predict(imgs_test.reshape(imgs_test.shape[0], 96, 96, 1))

for i in range(16):
    ax = fig.add_subplot(4, 4, i + 1, xticks=[], yticks=[])
    plot_keypoints(imgs_test[i], np.squeeze(points_test[i]))
